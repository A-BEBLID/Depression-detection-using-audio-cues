# %%
#1DCNN-LSTM_BoAW_MFCC
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Input, Conv1D, LSTM, Dense, Flatten, concatenate
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import History
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.model_selection import train_test_split
import os
import numpy as np

# Ensure TensorFlow uses CPU
tf.config.set_visible_devices([], 'GPU')

# Load CSV data
data = pd.read_csv('BoAWMFCC_features_modma.csv')
train_data, test_data = train_test_split(data, test_size=0.20, random_state=42)
X_train = train_data.iloc[:, :-1].values
y_train = train_data.iloc[:, -1].values
X_test = test_data.iloc[:, :-1].values
y_test = test_data.iloc[:, -1].values

# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Reshape data to fit the 1D CNN
X_train_cnn = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_cnn = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# Network parameters
input_shape = (X_train.shape[1], 1)  # Adapt input shape
lstm_units = 100
fnn_units = 100
num_classes = 1  # Binary classification

# Build 1D CNN + LSTM model
input_tensor = Input(shape=input_shape)
x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(input_tensor)
x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(x)
x = LSTM(lstm_units)(x)
lstm_output = Dense(fnn_units, activation='relu')(x)

# Build separate FNN model
fnn_input = Input(shape=(X_train.shape[1],))
y = Dense(fnn_units, activation='relu')(fnn_input)
y = Dense(fnn_units, activation='relu')(y)
y = Dense(fnn_units, activation='relu')(y)
fnn_output = Flatten()(y)

# Combine outputs of both models
combined = concatenate([lstm_output, fnn_output])

# Add final dense layers for classification
z = Dense(100, activation='relu')(combined)
z = Dense(100, activation='relu')(z)
output = Dense(num_classes, activation='sigmoid')(z)  # Binary classification

# Create model
model = Model(inputs=[input_tensor, fnn_input], outputs=output)

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Plot model structure
plot_model(model, to_file='model_plot.png', show_shapes=True)

# Define a function to train the model incrementally
def incremental_train(model, X_train_cnn, X_train, y_train, X_test_cnn, X_test, y_test, epochs_per_training=1, total_epochs=5):
    history_combined = {
        'accuracy': [],
        'val_accuracy': [],
        'loss': [],
        'val_loss': []
    }
    for epoch in range(total_epochs):
        print(f"Training epoch {epoch + 1}/{total_epochs}")
        history = model.fit([X_train_cnn, X_train], y_train, epochs=epochs_per_training, batch_size=32, validation_data=([X_test_cnn, X_test], y_test), verbose=1)
        
        # Save the model after each training session
        model.save(f'model_epoch_{epoch + 1}.keras')

        # Combine history
        for key in history.history:
            history_combined[key].extend(history.history[key])
    
    return history_combined

# Train the model incrementally and save it
history_combined = incremental_train(model, X_train_cnn, X_train, y_train, X_test_cnn, X_test, y_test, epochs_per_training=1, total_epochs=80)

# Predict and evaluate
y_pred_prob = model.predict([X_test_cnn, X_test])
y_pred = (y_pred_prob > 0.5).astype("int32")

# Calculate metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_pred_prob)

print(f'Accuracy: {accuracy:.3f}')
print(f'Precision: {precision:.3f}')
print(f'Recall: {recall:.3f}')
print(f'F1 Score: {f1:.3f}')
print(f'ROC AUC: {roc_auc:.3f}')

# Plot combined training history
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_combined['accuracy'], label='Training Accuracy')
plt.plot(history_combined['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history_combined['loss'], label='Training Loss')
plt.plot(history_combined['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Plot confusion matrix
conf_matrix = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(conf_matrix).plot()
plt.title('Confusion Matrix')
plt.show()

# Plot ROC curve
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)    │ (None, 100, 1)            │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_3 (InputLayer)    │ (None, 100)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_2 (Conv1D)             │ (None, 100, 64)           │             256 │ input_layer_2[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_8 (Dense)               │ (None, 100)               │          10,100 │ input_layer_3[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv1d_3 (Conv1D)             │ (None, 100, 64)           │          12,352 │ conv1d_2[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_9 (Dense)               │ (None, 100)               │          10,100 │ dense_8[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_1 (LSTM)                 │ (None, 100)               │          66,000 │ conv1d_3[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_10 (Dense)              │ (None, 100)               │          10,100 │ dense_9[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_7 (Dense)               │ (None, 100)               │          10,100 │ lstm_1[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten_1 (Flatten)           │ (None, 100)               │               0 │ dense_10[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate_1 (Concatenate)   │ (None, 200)               │               0 │ dense_7[0][0],             │
# │                               │                           │                 │ flatten_1[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_11 (Dense)              │ (None, 100)               │          20,100 │ concatenate_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_12 (Dense)              │ (None, 100)               │          10,100 │ dense_11[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_13 (Dense)              │ (None, 1)                 │             101 │ dense_12[0][0]             │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 149,309 (583.24 KB)
#  Trainable params: 149,309 (583.24 KB)
#  Non-trainable params: 0 (0.00 B)
# Training epoch 1/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6829 - loss: 0.5835 - val_accuracy: 0.8063 - val_loss: 0.4343
# Training epoch 2/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8292 - loss: 0.3819 - val_accuracy: 0.8264 - val_loss: 0.3958
# Training epoch 3/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.8706 - loss: 0.2918 - val_accuracy: 0.8264 - val_loss: 0.4129
# Training epoch 4/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9044 - loss: 0.2274 - val_accuracy: 0.8429 - val_loss: 0.4098
# Training epoch 5/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9362 - loss: 0.1686 - val_accuracy: 0.8298 - val_loss: 0.4861
# Training epoch 6/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9498 - loss: 0.1312 - val_accuracy: 0.8002 - val_loss: 0.5733
# Training epoch 7/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9566 - loss: 0.1317 - val_accuracy: 0.8412 - val_loss: 0.5883
# Training epoch 8/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9625 - loss: 0.0964 - val_accuracy: 0.8194 - val_loss: 0.7461
# Training epoch 9/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9598 - loss: 0.0989 - val_accuracy: 0.8246 - val_loss: 0.7454
# Training epoch 10/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9774 - loss: 0.0680 - val_accuracy: 0.8237 - val_loss: 0.8508
# Training epoch 11/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9824 - loss: 0.0513 - val_accuracy: 0.8141 - val_loss: 0.8333
# Training epoch 12/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9917 - loss: 0.0313 - val_accuracy: 0.8333 - val_loss: 0.7893
# Training epoch 13/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.9886 - loss: 0.0327 - val_accuracy: 0.8342 - val_loss: 0.8160
# Training epoch 14/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9865 - loss: 0.0372 - val_accuracy: 0.8255 - val_loss: 0.9629
# Training epoch 15/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9942 - loss: 0.0232 - val_accuracy: 0.8316 - val_loss: 0.8124
# Training epoch 16/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9909 - loss: 0.0301 - val_accuracy: 0.8351 - val_loss: 0.9319
# Training epoch 17/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9948 - loss: 0.0150 - val_accuracy: 0.8141 - val_loss: 0.9993
# Training epoch 18/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9866 - loss: 0.0361 - val_accuracy: 0.8316 - val_loss: 1.1111
# Training epoch 19/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9885 - loss: 0.0306 - val_accuracy: 0.8202 - val_loss: 0.7380
# Training epoch 20/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9895 - loss: 0.0336 - val_accuracy: 0.8124 - val_loss: 1.0132
# Training epoch 21/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9939 - loss: 0.0171 - val_accuracy: 0.8298 - val_loss: 1.1134
# Training epoch 22/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9919 - loss: 0.0296 - val_accuracy: 0.8211 - val_loss: 0.9354
# Training epoch 23/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9979 - loss: 0.0106 - val_accuracy: 0.8342 - val_loss: 1.1198
# Training epoch 24/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9918 - loss: 0.0206 - val_accuracy: 0.8255 - val_loss: 0.9473
# Training epoch 25/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9946 - loss: 0.0187 - val_accuracy: 0.8298 - val_loss: 0.9941
# Training epoch 26/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9950 - loss: 0.0172 - val_accuracy: 0.8351 - val_loss: 1.1098
# Training epoch 27/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9924 - loss: 0.0242 - val_accuracy: 0.8255 - val_loss: 1.0606
# Training epoch 28/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9971 - loss: 0.0107 - val_accuracy: 0.8290 - val_loss: 1.0942
# Training epoch 29/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9960 - loss: 0.0111 - val_accuracy: 0.8290 - val_loss: 1.1990
# Training epoch 30/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9954 - loss: 0.0134 - val_accuracy: 0.8298 - val_loss: 1.1319
# Training epoch 31/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9871 - loss: 0.0424 - val_accuracy: 0.8246 - val_loss: 0.9748
# Training epoch 32/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9904 - loss: 0.0235 - val_accuracy: 0.8264 - val_loss: 1.0594
# Training epoch 33/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9977 - loss: 0.0081 - val_accuracy: 0.8351 - val_loss: 1.1872
# Training epoch 34/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9972 - loss: 0.0098 - val_accuracy: 0.8325 - val_loss: 1.2858
# Training epoch 35/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9928 - loss: 0.0214 - val_accuracy: 0.8229 - val_loss: 1.1778
# Training epoch 36/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9888 - loss: 0.0381 - val_accuracy: 0.8237 - val_loss: 1.0712
# Training epoch 37/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9914 - loss: 0.0257 - val_accuracy: 0.8264 - val_loss: 1.1483
# Training epoch 38/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9937 - loss: 0.0185 - val_accuracy: 0.8150 - val_loss: 1.1741
# Training epoch 39/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9973 - loss: 0.0113 - val_accuracy: 0.8002 - val_loss: 1.3182
# Training epoch 40/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9929 - loss: 0.0217 - val_accuracy: 0.8229 - val_loss: 1.0799
# Training epoch 41/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9942 - loss: 0.0144 - val_accuracy: 0.8264 - val_loss: 1.3670
# Training epoch 42/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9993 - loss: 0.0023 - val_accuracy: 0.8211 - val_loss: 1.4033
# Training epoch 43/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9991 - loss: 0.0047 - val_accuracy: 0.8246 - val_loss: 1.5188
# Training epoch 44/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9993 - loss: 0.0038 - val_accuracy: 0.8255 - val_loss: 1.5860
# Training epoch 45/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9999 - loss: 6.0322e-04 - val_accuracy: 0.8255 - val_loss: 1.6391
# Training epoch 46/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9944 - loss: 0.0161 - val_accuracy: 0.8246 - val_loss: 0.8811
# Training epoch 47/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9956 - loss: 0.0199 - val_accuracy: 0.8211 - val_loss: 0.9311
# Training epoch 48/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9919 - loss: 0.0264 - val_accuracy: 0.8281 - val_loss: 1.0235
# Training epoch 49/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9887 - loss: 0.0251 - val_accuracy: 0.8377 - val_loss: 1.2952
# Training epoch 50/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9952 - loss: 0.0206 - val_accuracy: 0.8246 - val_loss: 1.0304
# Training epoch 51/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9971 - loss: 0.0132 - val_accuracy: 0.8342 - val_loss: 1.2037
# Training epoch 52/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9988 - loss: 0.0047 - val_accuracy: 0.8194 - val_loss: 1.3395
# Training epoch 53/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9969 - loss: 0.0101 - val_accuracy: 0.8307 - val_loss: 1.3265
# Training epoch 54/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9954 - loss: 0.0141 - val_accuracy: 0.8237 - val_loss: 1.4129
# Training epoch 55/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9987 - loss: 0.0053 - val_accuracy: 0.8211 - val_loss: 1.2958
# Training epoch 56/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step - accuracy: 0.9975 - loss: 0.0058 - val_accuracy: 0.8211 - val_loss: 1.4875
# Training epoch 57/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9970 - loss: 0.0119 - val_accuracy: 0.8072 - val_loss: 1.1218
# Training epoch 58/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9987 - loss: 0.0058 - val_accuracy: 0.8202 - val_loss: 1.6694
# Training epoch 59/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9968 - loss: 0.0222 - val_accuracy: 0.8176 - val_loss: 0.9198
# Training epoch 60/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9943 - loss: 0.0223 - val_accuracy: 0.8141 - val_loss: 0.9763
# Training epoch 61/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9927 - loss: 0.0208 - val_accuracy: 0.8194 - val_loss: 1.1399
# Training epoch 62/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9961 - loss: 0.0154 - val_accuracy: 0.8194 - val_loss: 1.3000
# Training epoch 63/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9928 - loss: 0.0225 - val_accuracy: 0.8377 - val_loss: 1.1935
# Training epoch 64/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9929 - loss: 0.0181 - val_accuracy: 0.8272 - val_loss: 1.2771
# Training epoch 65/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - accuracy: 0.9966 - loss: 0.0101 - val_accuracy: 0.8386 - val_loss: 1.4884
# Training epoch 66/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9970 - loss: 0.0071 - val_accuracy: 0.8281 - val_loss: 1.6409
# Training epoch 67/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9992 - loss: 0.0035 - val_accuracy: 0.8264 - val_loss: 1.2808
# Training epoch 68/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9973 - loss: 0.0119 - val_accuracy: 0.8141 - val_loss: 1.6244
# Training epoch 69/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 25ms/step - accuracy: 0.9960 - loss: 0.0226 - val_accuracy: 0.8220 - val_loss: 1.3375
# Training epoch 70/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 21ms/step - accuracy: 0.9950 - loss: 0.0191 - val_accuracy: 0.8220 - val_loss: 1.2526
# Training epoch 71/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9977 - loss: 0.0082 - val_accuracy: 0.8220 - val_loss: 1.3180
# Training epoch 72/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - accuracy: 0.9975 - loss: 0.0106 - val_accuracy: 0.8290 - val_loss: 1.4585
# Training epoch 73/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9955 - loss: 0.0145 - val_accuracy: 0.8264 - val_loss: 0.9707
# Training epoch 74/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 5s 32ms/step - accuracy: 0.9939 - loss: 0.0177 - val_accuracy: 0.8403 - val_loss: 1.2454
# Training epoch 75/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9976 - loss: 0.0091 - val_accuracy: 0.8394 - val_loss: 1.4301
# Training epoch 76/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9985 - loss: 0.0056 - val_accuracy: 0.8377 - val_loss: 1.4392
# Training epoch 77/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9970 - loss: 0.0096 - val_accuracy: 0.8290 - val_loss: 1.3611
# Training epoch 78/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9981 - loss: 0.0070 - val_accuracy: 0.8368 - val_loss: 1.1983
# Training epoch 79/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9989 - loss: 0.0046 - val_accuracy: 0.8229 - val_loss: 1.3972
# Training epoch 80/80
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9968 - loss: 0.0113 - val_accuracy: 0.8316 - val_loss: 1.2979
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Accuracy: 0.832
# Precision: 0.778
# Recall: 0.847
# F1 Score: 0.811
# ROC AUC: 0.903
